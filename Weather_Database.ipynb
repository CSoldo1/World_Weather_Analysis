# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %%
# %pwd
# Out:
# 'C:\\Users\\chris\\Desktop\\Data_Analytics_Class\\Module_6\\World_Weather_Analysis\\Weather_Database'

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 748

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# %%
from config import api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&lang=en&APPID=" + api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        current_description = city_weather["weather"]
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = current_description[0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')    
       
    # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
                        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cabo san lucas
# Processing Record 2 of Set 1 | saint george
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | altamira
# Processing Record 5 of Set 1 | ahuimanu
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | groditz
# City not found. Skipping...
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | coquimbo
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | sur
# Processing Record 13 of Set 1 | ostrovnoy
# Processing Record 14 of Set 1 | sangmelima
# Processing Record 15 of Set 1 | punta de piedra
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | mar del plata
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | tumaco
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | bonavista
# Processing Record 26 of Set 1 | tilichiki
# Processing Record 27 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 1 | trofors
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | indian head
# Processing Record 31 of Set 1 | khani
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | usinsk
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | coahuayana
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | soyo
# Processing Record 40 of Set 1 | jaora
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | nanortalik
# Processing Record 43 of Set 1 | sindor
# Processing Record 44 of Set 1 | gulshat
# City not found. Skipping...
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | okhotsk
# Processing Record 47 of Set 1 | muros
# Processing Record 48 of Set 1 | cherskiy
# Processing Record 49 of Set 1 | mount isa
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 2 | pevek
# Processing Record 3 of Set 2 | ejea de los caballeros
# Processing Record 4 of Set 2 | college
# Processing Record 5 of Set 2 | thinadhoo
# Processing Record 6 of Set 2 | viedma
# Processing Record 7 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 2 | abalak
# Processing Record 9 of Set 2 | maniitsoq
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | bethel
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | kavaratti
# Processing Record 16 of Set 2 | vardo
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | nome
# Processing Record 19 of Set 2 | haines junction
# Processing Record 20 of Set 2 | lavrentiya
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | provideniya
# Processing Record 23 of Set 2 | kruisfontein
# Processing Record 24 of Set 2 | grand gaube
# Processing Record 25 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 2 | babushkin
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | tiksi
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | hirara
# Processing Record 31 of Set 2 | bushehr
# Processing Record 32 of Set 2 | norman wells
# Processing Record 33 of Set 2 | lesosibirsk
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 2 | chunhuhub
# Processing Record 36 of Set 2 | cape town
# Processing Record 37 of Set 2 | coihaique
# Processing Record 38 of Set 2 | gamba
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | zhaoyuan
# Processing Record 41 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | saint anthony
# Processing Record 45 of Set 2 | port hardy
# Processing Record 46 of Set 2 | los llanos de aridane
# Processing Record 47 of Set 2 | aras
# Processing Record 48 of Set 2 | damavand
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 2 | avarua
# Processing Record 1 of Set 3 | vila velha
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | auki
# Processing Record 4 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 3 | tasiilaq
# Processing Record 6 of Set 3 | ust-koksa
# Processing Record 7 of Set 3 | labuhan
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | inverell
# Processing Record 10 of Set 3 | kaeo
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | sorgun
# Processing Record 13 of Set 3 | naryan-mar
# Processing Record 14 of Set 3 | cockburn town
# Processing Record 15 of Set 3 | berdigestyakh
# Processing Record 16 of Set 3 | bogotol
# Processing Record 17 of Set 3 | aleppo
# Processing Record 18 of Set 3 | north bend
# Processing Record 19 of Set 3 | djenne
# Processing Record 20 of Set 3 | dabat
# Processing Record 21 of Set 3 | hambantota
# Processing Record 22 of Set 3 | la ronge
# Processing Record 23 of Set 3 | srednekolymsk
# Processing Record 24 of Set 3 | laguna
# Processing Record 25 of Set 3 | koshurnikovo
# Processing Record 26 of Set 3 | villa carlos paz
# Processing Record 27 of Set 3 | bobo dioulasso
# Processing Record 28 of Set 3 | taksimo
# Processing Record 29 of Set 3 | richards bay
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | kirakira
# Processing Record 32 of Set 3 | clyde river
# Processing Record 33 of Set 3 | mahebourg
# Processing Record 34 of Set 3 | khatanga
# Processing Record 35 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 36 of Set 3 | meulaboh
# Processing Record 37 of Set 3 | tuatapere
# Processing Record 38 of Set 3 | wanning
# Processing Record 39 of Set 3 | royan
# Processing Record 40 of Set 3 | dingle
# Processing Record 41 of Set 3 | chapais
# Processing Record 42 of Set 3 | erzincan
# Processing Record 43 of Set 3 | saldanha
# Processing Record 44 of Set 3 | mongoumba
# Processing Record 45 of Set 3 | tayshet
# Processing Record 46 of Set 3 | ishigaki
# Processing Record 47 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 3 | basco
# Processing Record 49 of Set 3 | amapa
# Processing Record 50 of Set 3 | banda aceh
# Processing Record 1 of Set 4 | chernyshevskiy
# Processing Record 2 of Set 4 | luderitz
# Processing Record 3 of Set 4 | kudahuvadhoo
# Processing Record 4 of Set 4 | vandra
# Processing Record 5 of Set 4 | ornskoldsvik
# Processing Record 6 of Set 4 | gizo
# Processing Record 7 of Set 4 | baruun-urt
# Processing Record 8 of Set 4 | esil
# Processing Record 9 of Set 4 | ilebo
# Processing Record 10 of Set 4 | pasighat
# Processing Record 11 of Set 4 | sitka
# Processing Record 12 of Set 4 | nikolskoye
# Processing Record 13 of Set 4 | kathmandu
# Processing Record 14 of Set 4 | sao filipe
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | mongu
# Processing Record 17 of Set 4 | albion
# Processing Record 18 of Set 4 | tsumeb
# Processing Record 19 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 4 | balilihan
# Processing Record 21 of Set 4 | tura
# Processing Record 22 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 23 of Set 4 | naze
# Processing Record 24 of Set 4 | chicama
# Processing Record 25 of Set 4 | narsaq
# Processing Record 26 of Set 4 | valadares
# Processing Record 27 of Set 4 | ponta do sol
# Processing Record 28 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 4 | burica
# City not found. Skipping...
# Processing Record 30 of Set 4 | cayenne
# Processing Record 31 of Set 4 | guangyuan
# Processing Record 32 of Set 4 | iranshahr
# Processing Record 33 of Set 4 | baruipur
# Processing Record 34 of Set 4 | adrar
# Processing Record 35 of Set 4 | maningrida
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | olafsvik
# Processing Record 38 of Set 4 | lauf
# Processing Record 39 of Set 4 | katsuura
# Processing Record 40 of Set 4 | rundu
# Processing Record 41 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 4 | assiniboia
# Processing Record 43 of Set 4 | baker city
# Processing Record 44 of Set 4 | fomboni
# Processing Record 45 of Set 4 | shimoda
# Processing Record 46 of Set 4 | tual
# Processing Record 47 of Set 4 | klaksvik
# Processing Record 48 of Set 4 | pacific grove
# Processing Record 49 of Set 4 | les cayes
# Processing Record 50 of Set 4 | hay river
# Processing Record 1 of Set 5 | dunedin
# Processing Record 2 of Set 5 | san juan
# Processing Record 3 of Set 5 | bengkulu
# Processing Record 4 of Set 5 | kendari
# Processing Record 5 of Set 5 | kieta
# Processing Record 6 of Set 5 | wewak
# Processing Record 7 of Set 5 | jvari
# Processing Record 8 of Set 5 | new norfolk
# Processing Record 9 of Set 5 | nyurba
# Processing Record 10 of Set 5 | port augusta
# Processing Record 11 of Set 5 | leh
# Processing Record 12 of Set 5 | maragogi
# Processing Record 13 of Set 5 | kahului
# Processing Record 14 of Set 5 | xiangdong
# City not found. Skipping...
# Processing Record 15 of Set 5 | camapua
# Processing Record 16 of Set 5 | lompoc
# Processing Record 17 of Set 5 | taltal
# Processing Record 18 of Set 5 | kishapu
# Processing Record 19 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 20 of Set 5 | djambala
# Processing Record 21 of Set 5 | pristen
# Processing Record 22 of Set 5 | upernavik
# Processing Record 23 of Set 5 | espanola
# Processing Record 24 of Set 5 | bairiki
# Processing Record 25 of Set 5 | asyut
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 28 of Set 5 | acajutla
# Processing Record 29 of Set 5 | evensk
# Processing Record 30 of Set 5 | iqaluit
# Processing Record 31 of Set 5 | altay
# Processing Record 32 of Set 5 | uzumlu
# City not found. Skipping...
# Processing Record 33 of Set 5 | mahon
# Processing Record 34 of Set 5 | mazagao
# Processing Record 35 of Set 5 | lazaro cardenas
# Processing Record 36 of Set 5 | arraial do cabo
# Processing Record 37 of Set 5 | thilogne
# City not found. Skipping...
# Processing Record 38 of Set 5 | ust-nera
# Processing Record 39 of Set 5 | qaanaaq
# Processing Record 40 of Set 5 | sioux lookout
# Processing Record 41 of Set 5 | hamilton
# Processing Record 42 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 43 of Set 5 | gao
# Processing Record 44 of Set 5 | camana
# Processing Record 45 of Set 5 | burnie
# Processing Record 46 of Set 5 | dawson creek
# Processing Record 47 of Set 5 | fortuna
# Processing Record 48 of Set 5 | pinawa
# Processing Record 49 of Set 5 | hami
# Processing Record 50 of Set 5 | oyem
# Processing Record 1 of Set 6 | george
# Processing Record 2 of Set 6 | kasra
# City not found. Skipping...
# Processing Record 3 of Set 6 | antalaha
# Processing Record 4 of Set 6 | lilongwe
# Processing Record 5 of Set 6 | santa cruz
# Processing Record 6 of Set 6 | kaitangata
# Processing Record 7 of Set 6 | salinas
# Processing Record 8 of Set 6 | codrington
# Processing Record 9 of Set 6 | svetlaya
# Processing Record 10 of Set 6 | srivardhan
# Processing Record 11 of Set 6 | emerald
# Processing Record 12 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 6 | pangody
# Processing Record 14 of Set 6 | svetlogorsk
# Processing Record 15 of Set 6 | torbay
# Processing Record 16 of Set 6 | georgetown
# Processing Record 17 of Set 6 | oktyabrskoye
# Processing Record 18 of Set 6 | bambanglipuro
# Processing Record 19 of Set 6 | umm kaddadah
# Processing Record 20 of Set 6 | erenhot
# Processing Record 21 of Set 6 | bundi
# Processing Record 22 of Set 6 | plettenberg bay
# Processing Record 23 of Set 6 | teya
# Processing Record 24 of Set 6 | fairbanks
# Processing Record 25 of Set 6 | shellbrook
# Processing Record 26 of Set 6 | kijang
# Processing Record 27 of Set 6 | porosozero
# Processing Record 28 of Set 6 | meilu
# City not found. Skipping...
# Processing Record 29 of Set 6 | praia
# Processing Record 30 of Set 6 | sao miguel
# Processing Record 31 of Set 6 | katunino
# Processing Record 32 of Set 6 | puerto colombia
# Processing Record 33 of Set 6 | novyy urgal
# Processing Record 34 of Set 6 | lagoa
# Processing Record 35 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 6 | yizheng
# Processing Record 37 of Set 6 | weinan
# Processing Record 38 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 6 | eureka
# Processing Record 40 of Set 6 | chernaya kholunitsa
# Processing Record 41 of Set 6 | ewa beach
# Processing Record 42 of Set 6 | zonalnaya stantsiya
# Processing Record 43 of Set 6 | saint-augustin
# Processing Record 44 of Set 6 | apt
# Processing Record 45 of Set 6 | tokoroa
# Processing Record 46 of Set 6 | jacksonville
# Processing Record 47 of Set 6 | tommot
# Processing Record 48 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 6 | futtsu
# Processing Record 50 of Set 6 | tabuk
# Processing Record 1 of Set 7 | vestmannaeyjar
# Processing Record 2 of Set 7 | praia da vitoria
# Processing Record 3 of Set 7 | geraldton
# Processing Record 4 of Set 7 | vaovai
# City not found. Skipping...
# Processing Record 5 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 6 of Set 7 | kenai
# Processing Record 7 of Set 7 | arinos
# Processing Record 8 of Set 7 | atar
# Processing Record 9 of Set 7 | kashi
# Processing Record 10 of Set 7 | satka
# Processing Record 11 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 7 | yenagoa
# Processing Record 13 of Set 7 | zatyshshya
# Processing Record 14 of Set 7 | fort nelson
# Processing Record 15 of Set 7 | bend
# Processing Record 16 of Set 7 | melnikovo
# Processing Record 17 of Set 7 | half moon bay
# Processing Record 18 of Set 7 | san patricio
# Processing Record 19 of Set 7 | carahue
# Processing Record 20 of Set 7 | shelburne
# Processing Record 21 of Set 7 | lenoir
# Processing Record 22 of Set 7 | port blair
# Processing Record 23 of Set 7 | constantine
# Processing Record 24 of Set 7 | esperance
# Processing Record 25 of Set 7 | rocha
# Processing Record 26 of Set 7 | sabang
# Processing Record 27 of Set 7 | rabo de peixe
# Processing Record 28 of Set 7 | kavieng
# Processing Record 29 of Set 7 | trincomalee
# Processing Record 30 of Set 7 | valparaiso
# Processing Record 31 of Set 7 | shirokiy
# Processing Record 32 of Set 7 | baghdad
# Processing Record 33 of Set 7 | tambovka
# Processing Record 34 of Set 7 | shingu
# Processing Record 35 of Set 7 | ahipara
# Processing Record 36 of Set 7 | kaifeng
# Processing Record 37 of Set 7 | cidreira
# Processing Record 38 of Set 7 | inuvik
# Processing Record 39 of Set 7 | poum
# Processing Record 40 of Set 7 | sept-iles
# Processing Record 41 of Set 7 | kuah
# Processing Record 42 of Set 7 | lasa
# Processing Record 43 of Set 7 | guelph
# Processing Record 44 of Set 7 | omboue
# Processing Record 45 of Set 7 | lalawigan
# Processing Record 46 of Set 7 | mareeba
# Processing Record 47 of Set 7 | roebourne
# Processing Record 48 of Set 7 | sompeta
# Processing Record 49 of Set 7 | port lincoln
# Processing Record 50 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 8 | steinbach
# Processing Record 2 of Set 8 | korla
# Processing Record 3 of Set 8 | shitanjing
# Processing Record 4 of Set 8 | priyutnoye
# Processing Record 5 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 8 | koupela
# Processing Record 7 of Set 8 | buesaco
# Processing Record 8 of Set 8 | petrivka
# Processing Record 9 of Set 8 | mount gambier
# Processing Record 10 of Set 8 | tomatlan
# Processing Record 11 of Set 8 | talnakh
# Processing Record 12 of Set 8 | broome
# Processing Record 13 of Set 8 | byron bay
# Processing Record 14 of Set 8 | bayan
# Processing Record 15 of Set 8 | malpe
# Processing Record 16 of Set 8 | gachala
# Processing Record 17 of Set 8 | rawson
# Processing Record 18 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 19 of Set 8 | berlevag
# Processing Record 20 of Set 8 | agadez
# Processing Record 21 of Set 8 | avera
# Processing Record 22 of Set 8 | gallup
# Processing Record 23 of Set 8 | lugovoy
# Processing Record 24 of Set 8 | margate
# Processing Record 25 of Set 8 | puerto madryn
# Processing Record 26 of Set 8 | buta
# Processing Record 27 of Set 8 | touros
# Processing Record 28 of Set 8 | miles city
# Processing Record 29 of Set 8 | siocon
# Processing Record 30 of Set 8 | asau
# Processing Record 31 of Set 8 | bereda
# Processing Record 32 of Set 8 | ortona
# Processing Record 33 of Set 8 | kongolo
# Processing Record 34 of Set 8 | saint paul
# Processing Record 35 of Set 8 | kondinskoye
# Processing Record 36 of Set 8 | pitimbu
# Processing Record 37 of Set 8 | leningradskiy
# Processing Record 38 of Set 8 | den helder
# Processing Record 39 of Set 8 | parfenyevo
# Processing Record 40 of Set 8 | nabire
# Processing Record 41 of Set 8 | rantepao
# Processing Record 42 of Set 8 | kushmurun
# Processing Record 43 of Set 8 | palenque
# Processing Record 44 of Set 8 | tapes
# Processing Record 45 of Set 8 | tautira
# Processing Record 46 of Set 8 | matagami
# Processing Record 47 of Set 8 | immokalee
# Processing Record 48 of Set 8 | xinyu
# Processing Record 49 of Set 8 | bathsheba
# Processing Record 50 of Set 8 | aykhal
# Processing Record 1 of Set 9 | mehamn
# Processing Record 2 of Set 9 | san quintin
# Processing Record 3 of Set 9 | owando
# Processing Record 4 of Set 9 | vila franca do campo
# Processing Record 5 of Set 9 | itoman
# Processing Record 6 of Set 9 | ergani
# Processing Record 7 of Set 9 | gushikawa
# Processing Record 8 of Set 9 | mizdah
# Processing Record 9 of Set 9 | manokwari
# Processing Record 10 of Set 9 | cavalcante
# Processing Record 11 of Set 9 | tanete
# Processing Record 12 of Set 9 | cervo
# Processing Record 13 of Set 9 | vestmanna
# Processing Record 14 of Set 9 | mikhaylovskoye
# Processing Record 15 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 9 | moerai
# Processing Record 17 of Set 9 | sakakah
# Processing Record 18 of Set 9 | zapresic
# Processing Record 19 of Set 9 | srandakan
# Processing Record 20 of Set 9 | ancud
# Processing Record 21 of Set 9 | fare
# Processing Record 22 of Set 9 | cartagena
# Processing Record 23 of Set 9 | sao joao da barra
# Processing Record 24 of Set 9 | mayumba
# Processing Record 25 of Set 9 | constitucion
# Processing Record 26 of Set 9 | sumbe
# Processing Record 27 of Set 9 | sao pedro do sul
# Processing Record 28 of Set 9 | treinta y tres
# Processing Record 29 of Set 9 | bonthe
# Processing Record 30 of Set 9 | victoria
# Processing Record 31 of Set 9 | beaver dam
# Processing Record 32 of Set 9 | itaituba
# Processing Record 33 of Set 9 | marystown
# Processing Record 34 of Set 9 | pierre
# Processing Record 35 of Set 9 | wainwright
# Processing Record 36 of Set 9 | dodoma
# Processing Record 37 of Set 9 | korem
# Processing Record 38 of Set 9 | dossor
# Processing Record 39 of Set 9 | normandin
# Processing Record 40 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 41 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 9 | menongue
# Processing Record 43 of Set 9 | anadyr
# Processing Record 44 of Set 9 | zhangye
# Processing Record 45 of Set 9 | pulandian
# Processing Record 46 of Set 9 | carroll
# Processing Record 47 of Set 9 | laredo
# Processing Record 48 of Set 9 | saint-ambroise
# Processing Record 49 of Set 9 | umm jarr
# City not found. Skipping...
# Processing Record 50 of Set 9 | chiredzi
# Processing Record 1 of Set 10 | charters towers
# Processing Record 2 of Set 10 | denpasar
# Processing Record 3 of Set 10 | iskateley
# Processing Record 4 of Set 10 | mogadishu
# Processing Record 5 of Set 10 | novo aripuana
# Processing Record 6 of Set 10 | reconquista
# Processing Record 7 of Set 10 | acapulco
# Processing Record 8 of Set 10 | makakilo city
# Processing Record 9 of Set 10 | samarai
# Processing Record 10 of Set 10 | namatanai
# Processing Record 11 of Set 10 | sorland
# Processing Record 12 of Set 10 | belmonte
# Processing Record 13 of Set 10 | iquitos
# Processing Record 14 of Set 10 | bam
# Processing Record 15 of Set 10 | sisimiut
# Processing Record 16 of Set 10 | rosita
# Processing Record 17 of Set 10 | college place
# Processing Record 18 of Set 10 | kolokani
# Processing Record 19 of Set 10 | polaniec
# Processing Record 20 of Set 10 | catamarca
# Processing Record 21 of Set 10 | esmeralda
# Processing Record 22 of Set 10 | vysokogornyy
# Processing Record 23 of Set 10 | itarema
# Processing Record 24 of Set 10 | presidencia roque saenz pena
# Processing Record 25 of Set 10 | grindavik
# Processing Record 26 of Set 10 | saint-denis
# Processing Record 27 of Set 10 | montepuez
# Processing Record 28 of Set 10 | cartagena del chaira
# Processing Record 29 of Set 10 | bambous virieux
# Processing Record 30 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 10 | mahajanga
# Processing Record 32 of Set 10 | nova olinda do norte
# Processing Record 33 of Set 10 | inongo
# Processing Record 34 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 10 | bac lieu
# Processing Record 36 of Set 10 | alekseyevsk
# Processing Record 37 of Set 10 | ciudad bolivar
# Processing Record 38 of Set 10 | muyezerskiy
# Processing Record 39 of Set 10 | bara
# Processing Record 40 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 41 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 10 | isangel
# Processing Record 43 of Set 10 | havre-saint-pierre
# Processing Record 44 of Set 10 | tabou
# Processing Record 45 of Set 10 | fatehabad
# Processing Record 46 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 10 | kautokeino
# Processing Record 48 of Set 10 | koltubanovskiy
# Processing Record 49 of Set 10 | charkhi dadri
# Processing Record 50 of Set 10 | ilo
# Processing Record 1 of Set 11 | hasaki
# Processing Record 2 of Set 11 | roald
# Processing Record 3 of Set 11 | maralal
# Processing Record 4 of Set 11 | russell
# Processing Record 5 of Set 11 | husavik
# Processing Record 6 of Set 11 | lentekhi
# Processing Record 7 of Set 11 | xapuri
# Processing Record 8 of Set 11 | necochea
# Processing Record 9 of Set 11 | bud
# Processing Record 10 of Set 11 | beringovskiy
# Processing Record 11 of Set 11 | azare
# Processing Record 12 of Set 11 | plaridel
# Processing Record 13 of Set 11 | lasem
# Processing Record 14 of Set 11 | yaan
# Processing Record 15 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 11 | cap malheureux
# Processing Record 17 of Set 11 | liberal
# Processing Record 18 of Set 11 | pochutla
# Processing Record 19 of Set 11 | guapo
# Processing Record 20 of Set 11 | iracoubo
# Processing Record 21 of Set 11 | ambon
# Processing Record 22 of Set 11 | grafton
# Processing Record 23 of Set 11 | gisborne
# Processing Record 24 of Set 11 | pimentel
# Processing Record 25 of Set 11 | chatham
# Processing Record 26 of Set 11 | comodoro rivadavia
# Processing Record 27 of Set 11 | ilulissat
# Processing Record 28 of Set 11 | gravdal
# Processing Record 29 of Set 11 | sistranda
# Processing Record 30 of Set 11 | kasongo-lunda
# Processing Record 31 of Set 11 | vao
# Processing Record 32 of Set 11 | chuzhou
# Processing Record 33 of Set 11 | kyren
# Processing Record 34 of Set 11 | axim
# Processing Record 35 of Set 11 | solginskiy
# Processing Record 36 of Set 11 | lorengau
# Processing Record 37 of Set 11 | bilma
# Processing Record 38 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 11 | templin
# Processing Record 40 of Set 11 | coruripe
# Processing Record 41 of Set 11 | komsomolets
# Processing Record 42 of Set 11 | the valley
# Processing Record 43 of Set 11 | lata
# Processing Record 44 of Set 11 | independence
# Processing Record 45 of Set 11 | ulaangom
# Processing Record 46 of Set 11 | kalmunai
# Processing Record 47 of Set 11 | sandovo
# Processing Record 48 of Set 11 | diyarb najm
# Processing Record 49 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 50 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 1 of Set 12 | golfito
# Processing Record 2 of Set 12 | mirnyy
# Processing Record 3 of Set 12 | portsmouth
# Processing Record 4 of Set 12 | riyadh
# Processing Record 5 of Set 12 | mana
# Processing Record 6 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 12 | pine bluff
# Processing Record 8 of Set 12 | tiarei
# Processing Record 9 of Set 12 | avila
# Processing Record 10 of Set 12 | inyonga
# Processing Record 11 of Set 12 | goderich
# Processing Record 12 of Set 12 | lerwick
# Processing Record 13 of Set 12 | saint-francois
# Processing Record 14 of Set 12 | rayong
# Processing Record 15 of Set 12 | laibin
# Processing Record 16 of Set 12 | losal
# Processing Record 17 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 12 | xiaoweizhai
# Processing Record 19 of Set 12 | nicoya
# Processing Record 20 of Set 12 | batagay
# Processing Record 21 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 22 of Set 12 | igrim
# Processing Record 23 of Set 12 | zhezkazgan
# Processing Record 24 of Set 12 | bucerias
# Processing Record 25 of Set 12 | isla vista
# Processing Record 26 of Set 12 | aygut
# Processing Record 27 of Set 12 | huilong
# Processing Record 28 of Set 12 | santa rosa
# Processing Record 29 of Set 12 | sarankhola
# Processing Record 30 of Set 12 | aguada de pasajeros
# Processing Record 31 of Set 12 | maumere
# Processing Record 32 of Set 12 | serov
# Processing Record 33 of Set 12 | otane
# Processing Record 34 of Set 12 | do gonbadan
# Processing Record 35 of Set 12 | karratha
# Processing Record 36 of Set 12 | santa fe
# Processing Record 37 of Set 12 | christchurch
# Processing Record 38 of Set 12 | akonolinga
# Processing Record 39 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 40 of Set 12 | sitrah
# Processing Record 41 of Set 12 | changping
# Processing Record 42 of Set 12 | salinopolis
# Processing Record 43 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 12 | shar
# Processing Record 45 of Set 12 | ulaanbaatar
# Processing Record 46 of Set 12 | houma
# Processing Record 47 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 12 | high level
# Processing Record 49 of Set 12 | mbandaka
# Processing Record 50 of Set 12 | oussouye
# Processing Record 1 of Set 13 | skara
# Processing Record 2 of Set 13 | kangaatsiaq
# Processing Record 3 of Set 13 | porto novo
# Processing Record 4 of Set 13 | salalah
# Processing Record 5 of Set 13 | marrakesh
# Processing Record 6 of Set 13 | faanui
# Processing Record 7 of Set 13 | benguela
# Processing Record 8 of Set 13 | bowen
# Processing Record 9 of Set 13 | okmulgee
# Processing Record 10 of Set 13 | kerchevskiy
# Processing Record 11 of Set 13 | rapid valley
# Processing Record 12 of Set 13 | borogontsy
# Processing Record 13 of Set 13 | sinnamary
# Processing Record 14 of Set 13 | arrifes
# Processing Record 15 of Set 13 | macamic
# Processing Record 16 of Set 13 | lahat
# Processing Record 17 of Set 13 | kaolinovo
# Processing Record 18 of Set 13 | kirovskiy
# Processing Record 19 of Set 13 | yatou
# Processing Record 20 of Set 13 | halifax
# Processing Record 21 of Set 13 | saint-pierre
# Processing Record 22 of Set 13 | kayerkan
# Processing Record 23 of Set 13 | jalu
# Processing Record 24 of Set 13 | batagay-alyta
# Processing Record 25 of Set 13 | aklavik
# Processing Record 26 of Set 13 | chaa-khol
# City not found. Skipping...
# Processing Record 27 of Set 13 | menomonie
# Processing Record 28 of Set 13 | antsohihy
# Processing Record 29 of Set 13 | portland
# Processing Record 30 of Set 13 | saeby
# Processing Record 31 of Set 13 | yulara
# Processing Record 32 of Set 13 | seybaplaya
# Processing Record 33 of Set 13 | ponta delgada
# Processing Record 34 of Set 13 | arawa
# Processing Record 35 of Set 13 | taoudenni
# Processing Record 36 of Set 13 | mathathane
# Processing Record 37 of Set 13 | bandarbeyla
# Processing Record 38 of Set 13 | san jeronimo
# Processing Record 39 of Set 13 | nokia
# Processing Record 40 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 41 of Set 13 | bafia
# Processing Record 42 of Set 13 | milkovo
# Processing Record 43 of Set 13 | teknaf
# Processing Record 44 of Set 13 | parksville
# Processing Record 45 of Set 13 | san policarpo
# Processing Record 46 of Set 13 | dom pedro
# Processing Record 47 of Set 13 | jumla
# Processing Record 48 of Set 13 | bayir
# Processing Record 49 of Set 13 | te anau
# Processing Record 50 of Set 13 | nishihara
# Processing Record 1 of Set 14 | blagoveshchensk
# Processing Record 2 of Set 14 | moose factory
# Processing Record 3 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 14 | marsabit
# Processing Record 5 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 14 | cuamba
# Processing Record 7 of Set 14 | balatonfenyves
# Processing Record 8 of Set 14 | gonbad-e qabus
# Processing Record 9 of Set 14 | peniche
# Processing Record 10 of Set 14 | timizart
# Processing Record 11 of Set 14 | seymchan
# Processing Record 12 of Set 14 | komsomolskiy
# Processing Record 13 of Set 14 | karakose
# City not found. Skipping...
# Processing Record 14 of Set 14 | pilar do sul
# Processing Record 15 of Set 14 | rongcheng
# Processing Record 16 of Set 14 | tiznit
# Processing Record 17 of Set 14 | guerrero negro
# Processing Record 18 of Set 14 | fuzhou
# Processing Record 19 of Set 14 | truckee
# Processing Record 20 of Set 14 | simoes
# Processing Record 21 of Set 14 | nizhniy odes
# Processing Record 22 of Set 14 | ivanteyevka
# Processing Record 23 of Set 14 | kodinsk
# Processing Record 24 of Set 14 | bouloupari
# Processing Record 25 of Set 14 | khirkiya
# Processing Record 26 of Set 14 | waddan
# Processing Record 27 of Set 14 | sembakung
# Processing Record 28 of Set 14 | duncan
# Processing Record 29 of Set 14 | asahikawa
# Processing Record 30 of Set 14 | hong gai
# Processing Record 31 of Set 14 | wanxian
# Processing Record 32 of Set 14 | nacala
# Processing Record 33 of Set 14 | beloha
# Processing Record 34 of Set 14 | tombouctou
# Processing Record 35 of Set 14 | turinskaya sloboda
# Processing Record 36 of Set 14 | baishishan
# Processing Record 37 of Set 14 | makueni
# Processing Record 38 of Set 14 | puri
# Processing Record 39 of Set 14 | vostok
# Processing Record 40 of Set 14 | tazovskiy
# Processing Record 41 of Set 14 | ilheus
# Processing Record 42 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 43 of Set 14 | bom jesus
# Processing Record 44 of Set 14 | rudbar
# Processing Record 45 of Set 14 | naples
# Processing Record 46 of Set 14 | devrek
# Processing Record 47 of Set 14 | soe
# Processing Record 48 of Set 14 | basoko
# Processing Record 49 of Set 14 | bubaque
# Processing Record 50 of Set 14 | papara
# Processing Record 1 of Set 15 | macusani
# Processing Record 2 of Set 15 | kununurra
# Processing Record 3 of Set 15 | jardim
# Processing Record 4 of Set 15 | begoro
# Processing Record 5 of Set 15 | ipameri
# Processing Record 6 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 15 | davila
# Processing Record 8 of Set 15 | segezha
# Processing Record 9 of Set 15 | bad durkheim
# Processing Record 10 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 15 | quatre cocos
# Processing Record 13 of Set 15 | jalingo
# Processing Record 14 of Set 15 | schoningen
# Processing Record 15 of Set 15 | iquique
# Processing Record 16 of Set 15 | biak
# Processing Record 17 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 15 | mayor pablo lagerenza
# Processing Record 19 of Set 15 | maraa
# Processing Record 20 of Set 15 | whitehorse
# Processing Record 21 of Set 15 | carinhanha
# Processing Record 22 of Set 15 | nalgonda
# Processing Record 23 of Set 15 | high rock
# Processing Record 24 of Set 15 | gemena
# Processing Record 25 of Set 15 | doha
# Processing Record 26 of Set 15 | cabedelo
# Processing Record 27 of Set 15 | minjur
# Processing Record 28 of Set 15 | yuanping
# Processing Record 29 of Set 15 | krasnoselkup
# Processing Record 30 of Set 15 | formosa do rio preto
# Processing Record 31 of Set 15 | san felipe
# Processing Record 32 of Set 15 | trowbridge
# Processing Record 33 of Set 15 | ambulu
# Processing Record 34 of Set 15 | stabat
# Processing Record 35 of Set 15 | thunder bay
# Processing Record 36 of Set 15 | puerto ayacucho
# Processing Record 37 of Set 15 | prince rupert
# Processing Record 38 of Set 15 | bulgan
# Processing Record 39 of Set 15 | agdas
# Processing Record 40 of Set 15 | impfondo
# Processing Record 41 of Set 15 | sulangan
# Processing Record 42 of Set 15 | huarmey
# Processing Record 43 of Set 15 | luganville
# Processing Record 44 of Set 15 | flinders
# Processing Record 45 of Set 15 | imeni poliny osipenko
# Processing Record 46 of Set 15 | cantagallo
# Processing Record 47 of Set 15 | aksu
# Processing Record 48 of Set 15 | bull savanna
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 683

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cabo San Lucas  22.8909 -109.9124     74.52        71          54
# 1    Saint George  37.1041 -113.5841     38.25        65           0
# 2       Busselton -33.6500  115.3333     52.56        66          12
# 3        Altamira  -3.2033  -52.2064     80.69        89          40
# 4        Ahuimanu  21.4447 -157.8378     76.75        75          75
# 5  Saint-Philippe -21.3585   55.7679     80.19        81          27
# 6     Yellowknife  62.4560 -114.3525     15.57        85          64
# 7      Chokurdakh  70.6333  147.9167    -19.14        98         100
# 8        Coquimbo -29.9533  -71.3436     60.53        77          75
# 9         Rikitea -23.1203 -134.9692     73.20        87          80
#
#    Wind Speed Country                 Date Current Description
# 0        8.77      MX  2022-11-11 12:16:09       broken clouds
# 1        5.75      US  2022-11-11 12:15:45           clear sky
# 2       11.56      AU  2022-11-11 12:19:46          few clouds
# 3        3.44      BR  2022-11-11 12:19:46    scattered clouds
# 4        4.61      US  2022-11-11 12:19:47       broken clouds
# 5        8.23      RE  2022-11-11 12:19:47    scattered clouds
# 6       15.01      CA  2022-11-11 12:15:18       broken clouds
# 7        6.40      RU  2022-11-11 12:19:48     overcast clouds
# 8        2.30      CL  2022-11-11 12:19:50       broken clouds
# 9        6.26      PF  2022-11-11 12:19:50       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
city_data_df = city_data_df.drop(['Date'], axis = 1)
# Display sample data
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cabo San Lucas      MX  22.8909 -109.9124     74.52        71          54
# 1    Saint George      US  37.1041 -113.5841     38.25        65           0
# 2       Busselton      AU -33.6500  115.3333     52.56        66          12
# 3        Altamira      BR  -3.2033  -52.2064     80.69        89          40
# 4        Ahuimanu      US  21.4447 -157.8378     76.75        75          75
#
#    Wind Speed Current Description
# 0        8.77       broken clouds
# 1        5.75           clear sky
# 2       11.56          few clouds
# 3        3.44    scattered clouds
# 4        4.61       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
display(city_data_df.dtypes)
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# %pwd
# Out:
# 'C:\\Users\\chris\\Desktop\\Data_Analytics_Class\\Module_6\\World_Weather_Analysis\\Weather_Database'

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
